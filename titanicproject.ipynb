# %%
import pandas as pd

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data["Age"])
plt.show()

# %%
plt.hist(data["Age"])
plt.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop(columns=["PassengerId","SibSp","Parch","Ticket","Fare"],inplace=True)
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age Cabin Embarked
# 0      male  22.0   NaN        S
# ...

# %%
data["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
data["Survived"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Survived"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Age"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Age"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Age"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
data["Pclass"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
data["Pclass"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Pclass"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Name"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
data["Name"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Name"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
data["Sex"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Sex"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Cabin"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cabin'>

# %%
data["Cabin"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data["Cabin"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Embarked"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Embarked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked'>

# %%
data["Embarked"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
