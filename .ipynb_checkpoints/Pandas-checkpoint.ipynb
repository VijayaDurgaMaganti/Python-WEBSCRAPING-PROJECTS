# %%
#pip install pandas

# %%
import pandas as pd
a=[10,20,30,40,50]
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
b=[12.0,22.4,78.9,35,4,45.8]
pd.Series(b)
# Out:
# 0    12.0
# 1    22.4
# 2    78.9
# 3    35.0
# 4     4.0
# 5    45.8
# dtype: float64

# %%
c=["durga","python","java","codegnan","fullstack"]
pd.Series(c)
# Out:
# 0        durga
# 1       python
# 2         java
# 3     codegnan
# 4    fullstack
# dtype: object

# %%
d=[True,False]
pd.Series(d)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
e=[1+2j,3+4j,9+10j,7+3j]
pd.Series(e)
# Out:
# 0    1.0+ 2.0j
# 1    3.0+ 4.0j
# 2    9.0+10.0j
# 3    7.0+ 3.0j
# dtype: complex128

# %%
f=[10,20,30,40,50]
pd.Series(f,index=['i','ii','iii','iv','v'])
# Out:
# i      10
# ii     20
# iii    30
# iv     40
# v      50
# dtype: int64

# %%
d=pd.DataFrame({"name":["pooja","purnima"],"marks":[70,75]})
d
# Out:
#       name  marks
# 0    pooja     70
# 1  purnima     75

# %%
data=pd.DataFrame({"name":["durga","pooja","sita"],"subjects":["python","java","dsa"],"percentage":[75,80,85]})
data
# Out:
#     name subjects  percentage
# 0  durga   python          75
# 1  pooja     java          80
# 2   sita      dsa          85

# %%
pd.read_csv("food.csv")
# Out:
#    sl.no       food              place
# 0      1       DOSA  KRISHNA RESIDENCY
# 1      2      POORI       BALAJI HOTEL
# 2      3    UTHAPAM      MAMATHA HOTEL
# 3      4   CHAPATHI     MANORAMA HOTEL
# 4      5  PANI PURI        TEMPTATIONS
# 5      6  DHAI PURI          PURI VURI
# 6      7   VADA PAV       SNACK STREET
# 7      8     SAMOSA       SAMOSA SINGH
# 8      9      PIZZA            DOMINOS
# 9     10       idly          sai hotel

# %%
pd.read_csv("books.csv")
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
pd.read_csv("C:\\Users\\hi\\Desktop\\Apr8\\durga\\books.csv")
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
pd.read_csv("data.csv")
# Out:
#            id  age  gender  income   education region loyalty_status  \
# 0           1   27    Male   40682    Bachelor   East           Gold
# 1           2   29    Male   15317     Masters   West        Regular
# 2           3   37    Male   38849    Bachelor   West         Silver
# 3           4   30    Male   11568  HighSchool  South        Regular
# 4           5   31  Female   46952     College  North        Regular
# ...       ...  ...     ...     ...         ...    ...            ...
# 99995   99996   31  Female   19691     College   West        Regular
# 99996   99997   36    Male   17428  HighSchool  South        Regular
# 99997   99998   29    Male   13222     College   West        Regular
# 99998   99999   31  Female   40093    Bachelor   West        Regular
# 99999  100000   35  Female   22249     College   West         Silver
#
#       purchase_frequency  purchase_amount product_category  promotion_usage  \
# ...
